# %%
from keras.models import load_model

model_path = "../model_save/TB3SR11.h5"
model = load_model(model_path)

print(model.input_shape)
# Out:
# Metal device set to: Apple M1 Pro
#
# systemMemory: 16.00 GB
# maxCacheSize: 5.33 GB
#
# (None, 960, 832, 2)

# %%
from keras.utils import plot_model

model.summary()
plot_model(model, show_shapes=True)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 960, 832, 2  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 480, 416, 32  1632        ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 480, 416, 32  128        ['conv2d[0][0]']
#  alization)                     )
#
#  leaky_re_lu (LeakyReLU)        (None, 480, 416, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 240, 208, 64  51264       ['leaky_re_lu[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 240, 208, 64  256        ['conv2d_1[0][0]']
#  rmalization)                   )
#
# ...

# %%
from global_utils.utils import convert_pred

music_path = "../Data/merge_sample/test_data/"
pred_path = "../Data/music/pred_sample_SR11/TB3/"
sample_rate = 110_000

convert_pred(model, music_path, pred_path, pattern="merge*", sample_rate=sample_rate)
# Out:
# Processing... [\] : [001/020]
# 2023-07-27 18:12:27.086202: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# Processing... [-] : [020/020]	 Done
